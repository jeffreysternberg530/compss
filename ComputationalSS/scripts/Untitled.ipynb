# %%
import pandas
df = pandas.read_csv("../data/City List.csv", index_col=0, encoding='utf-8')
#view our data. Note: 'NaN' indicates the value is missing
df
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
data = open("../data/City List.csv", encoding='utf-8').read()
city = data.split()

# %%
def anydup(thelist):
  seen = set()
  for x in thelist:
    if x in seen: print(x, True)
    seen.add(x)
  return False

# %%
anydup(city)
# Out:
# Town True
# City True
# Las True
# City True
# City True
# San True
# City True
# Ko True
# Ko True
# Ko True
# Nang True
# Ko True
# Ko True
# Phi True
# Chiang True
# Da True
# San True
# City True
# City True
# New True
# del True
# City True
# San True
# San True
# City True
# City True
# San True
# de True
# York True
# Lake True
# San True
# San True
# City True
# San True
# Jose True
# Louis True
# La True
# del True
# Porto True
# Salvador True
# Bogota True
# Santa True
# Puerto True
# Saint True
# Louis True
# Grande True
# West True
# Ko True
# Reykjavik True
# Port True
# Sao True
# Jose True
# City True
# Santa True
# FL" True
# City True
# del True
# Goiania True
# Yaounde True
# New True
# Taipei True
# City True
# Los True
# Palm True
# Bay True
# Miami True
# Beach True
# Beach True
# Santa True
# Port True
# City True
# Town True
# Palm True
# Springs True
# False

# %%
count = 0
for x in city:
    if x == "Reykjavik": 
        count = count+1

# %%
print(count)
# Out:
# 2

# %%
df.sort_values("City", ascending=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'City'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-9563cf7d9083> in <module>()
# ...
