# %%
# Import required libraries
from __future__ import division
import requests
import json
import math
import matplotlib.pyplot as plt
import time
import pandas
import csv
import seaborn as sns

# %matplotlib inline

# %%
# set key
key = "d63713f5fe3646b0a6ab66ae0b0e3d96"

# set base url
base_url = "https://api.nytimes.com/svc/search/v2/articlesearch.json"

#set range for our year
year_range = range(1986, 2018)

#create empty list varible
year_tuple = list()
for year in year_range:
    print(year)

    # set search parameters
    search_params = {"q": "sxsw",
                 "api-key": key,
                 "begin_date": str(year)+"0101",  # create year range from the element variable
                 "end_date": str(year)+"1231"}

    # make request
    r = requests.get(base_url, params=search_params)

    # wait 3 seconds for the GET request
    time.sleep(3)

    # convert to a dictionary
    data = json.loads(r.text)

    # get number of hits
    hits = data['response']['meta']['hits']
    print("number of hits: ", str(hits))
    year_tuple.append(tuple((year, hits)))
# Out:
# 1986
# number of hits:  0
# 1987
# number of hits:  0
# 1988
# number of hits:  0
# 1989
# number of hits:  0
# 1990
# number of hits:  0
# 1991
# number of hits:  0
# 1992
# number of hits:  0
# 1993
# number of hits:  1
# 1994
# number of hits:  0
# 1995
# number of hits:  1
# 1996
# number of hits:  0
# 1997
# number of hits:  0
# 1998
# number of hits:  1
# 1999
# number of hits:  1
# 2000
# number of hits:  2
# 2001
# number of hits:  1
# 2002
# number of hits:  0
# 2003
# number of hits:  0
# 2004
# number of hits:  2
# 2005
# number of hits:  4
# 2006
# number of hits:  6
# 2007
# number of hits:  3
# 2008
# number of hits:  48
# 2009
# number of hits:  79
# 2010
# number of hits:  123
# 2011
# number of hits:  64
# 2012
# number of hits:  63
# 2013
# number of hits:  57
# 2014
# number of hits:  50
# 2015
# number of hits:  65
# 2016
# number of hits:  40
# 2017
# number of hits:  17

# %%
df_years = pandas.DataFrame(year_tuple, columns = ["year", "count"])
df_years
# Out:
#     year  count
# 0   1986      0
# 1   1987      0
# 2   1988      0
# 3   1989      0
# 4   1990      0
# 5   1991      0
# 6   1992      0
# 7   1993      1
# 8   1994      0
# 9   1995      1
# 10  1996      0
# 11  1997      0
# 12  1998      1
# 13  1999      1
# 14  2000      2
# 15  2001      1
# 16  2002      0
# 17  2003      0
# 18  2004      2
# 19  2005      4
# 20  2006      6
# 21  2007      3
# 22  2008     48
# 23  2009     79
# 24  2010    123
# 25  2011     64
# 26  2012     63
# 27  2013     57
# 28  2014     50
# 29  2015     65
# 30  2016     40
# 31  2017     17

# %%
sns.pointplot(x='year', y='count', data = df_years)

# %%
# set key
key = "d63713f5fe3646b0a6ab66ae0b0e3d96"

# set base url
base_url = "https://api.nytimes.com/svc/search/v2/articlesearch.json"

# set search parameters
search_params = {"q": "sxsw",
                 "api-key": key,
                 "begin_date": "19930101",  # date must be in YYYYMMDD format
                 "end_date": "20181231"}

# make request
r = requests.get(base_url, params=search_params)

# wait 3 seconds for the GET request
time.sleep(3)

# convert to a dictionary
data = json.loads(r.text)

# get number of hits
hits = data['response']['meta']['hits']
print("number of hits: ", str(hits))

# get number of pages
pages = int(math.ceil(hits / 10))
print("number of pages: ", str(pages))
# Out:
# number of hits:  643
# number of pages:  65

# %%
# make an empty dataframe where we'll hold all of our docs for every page
all_docs = pandas.DataFrame()

# now we're ready to loop through the pages
for i in range(pages):
    print("collecting page", str(i))

    # set the page parameter
    search_params['page'] = i

    # make request
    r = requests.get(base_url, params=search_params)

    # get text and convert to a dictionary
    data = json.loads(r.text)

    # get just the docs
    docs = data['response']['docs']
    df_temp = pandas.DataFrame(docs)

    # add those docs to the dataframe
    all_docs = pandas.concat([all_docs, df_temp], ignore_index=True)

    time.sleep(10)  # pause between calls
# Out:
# collecting page 0
# collecting page 1
# collecting page 2
# collecting page 3
# collecting page 4
# collecting page 5
# collecting page 6
# collecting page 7
# collecting page 8
# collecting page 9
# collecting page 10
# collecting page 11
# collecting page 12
# collecting page 13
# collecting page 14
# collecting page 15
# collecting page 16
# collecting page 17
# collecting page 18
# collecting page 19
# collecting page 20
# collecting page 21
# collecting page 22
# collecting page 23
# collecting page 24
# collecting page 25
# collecting page 26
# collecting page 27
# collecting page 28
# collecting page 29
# collecting page 30
# collecting page 31
# collecting page 32
# collecting page 33
# collecting page 34
# collecting page 35
# collecting page 36
# collecting page 37
# collecting page 38
# collecting page 39
# collecting page 40
# collecting page 41
# collecting page 42
# collecting page 43
# collecting page 44
# collecting page 45
# collecting page 46
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     140             conn = connection.create_connection(
# --> 141                 (self.host, self.port), self.timeout, **extra_kw)
#     142
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      59
# ---> 60     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61         af, socktype, proto, canonname, sa = res
#
# ~/anaconda3/lib/python3.6/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     744     addrlist = []
# --> 745     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     746         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     345         try:
# --> 346             self._validate_conn(conn)
#     347         except (SocketTimeout, BaseSSLError) as e:
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     849         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 850             conn.connect()
#     851
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connection.py in connect(self)
#     283         # Add certificate verification
# --> 284         conn = self._new_conn()
#     285
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     149             raise NewConnectionError(
# --> 150                 self, "Failed to establish a new connection: %s" % e)
#     151
#
# NewConnectionError: <urllib3.connection.VerifiedHTTPSConnection object at 0x1a203db748>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     638             retries = retries.increment(method, url, error=e, _pool=self,
# --> 639                                         _stacktrace=sys.exc_info()[2])
#     640             retries.sleep()
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     387         if new_retry.is_exhausted():
# --> 388             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     389
#
# MaxRetryError: HTTPSConnectionPool(host='api.nytimes.com', port=443): Max retries exceeded with url: /svc/search/v2/articlesearch.json?q=sxsw&api-key=d63713f5fe3646b0a6ab66ae0b0e3d96&begin_date=19930101&end_date=20181231&page=46 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x1a203db748>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-7-e8f0700c83ed> in <module>()
#      10
#      11     # make request
# ---> 12     r = requests.get(base_url, params=search_params)
#      13
#      14     # get text and convert to a dictionary
#
# ~/anaconda3/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# ~/anaconda3/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ~/anaconda3/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# ~/anaconda3/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     506                 raise SSLError(e, request=request)
#     507
# --> 508             raise ConnectionError(e, request=request)
#     509
#     510         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='api.nytimes.com', port=443): Max retries exceeded with url: /svc/search/v2/articlesearch.json?q=sxsw&api-key=d63713f5fe3646b0a6ab66ae0b0e3d96&begin_date=19930101&end_date=20181231&page=46 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x1a203db748>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))

# %%
all_docs
# Out:
#                           _id  \
# 0    5ab11de8068401528a298e73
# 1    5aaab88d068401528a29650c
# 2    5aae92c9068401528a297d25
# 3    5aafab6b068401528a298250
# 4    5a72124310f40f00018bec7c
# 5    5aaee165068401528a297e5a
# 6    5aa68f2e068401528a29328c
# 7    5aa43a26068401528a292822
# 8    5aa6d6c9068401528a293573
# 9    5ab37920068401528a29ac41
# 10   5aa6a653068401528a2933b8
# 11   5aa67b18068401528a2931a8
# 12   5a57cce87c459f29e79b3819
# 13   5a3bf4e17c459f246b63c484
# 14   59b5b5ec7c459f246b622c7b
# 15   593034257c459f24986e2d9f
# 16   58ed29d27c459f24986d9aa1
# 17   58d04dbb7c459f247805ced0
# 18   58d04ec17c459f247805ced4
# 19   58f727277c459f24986dadef
# 20   58c821927c459f247805bc1d
# 21   58bf4d4c7c459f247962dcd3
# 22   58cf04517c459f247805cbdb
# 23   58d597647c459f24986d64f2
# 24   58cf0eee7c459f247805cbea
# 25   58cac02d7c459f247805c3a5
# 26   58b3f8ad7c459f2525d1eb42
# 27   589938457c459f2525d1acaf
# 28   5890ecc97c459f2525d19ab0
# 29   586e97b87c459f2525d1507c
# ..                        ...
# 430  5444ab5238f0d82782d9be81
# 431  5444868a38f0d82782d9bb66
# 432  4fd39a468eb7c8105d8d73d3
# 433  544459ad38f0d82782d9b7ad
# 434  59c135ed7c459f246b628435
# 435  4fd39a2f8eb7c8105d8d7061
# 436  59c2bfbd7c459f246b629205
# 437  5247e27638f0d8198973e77b
# 438  59c2bfc47c459f246b629207
# 439  504a8bd11c22dfde670c3f37
# 440  4fd399ff8eb7c8105d8d6b09
# 441  4fd39a5c8eb7c8105d8d78a5
# 442  59c2bfd27c459f246b62920c
# 443  544432a338f0d82782d9b442
# 444  59c2bfd27c459f246b62920a
# 445  4fd39a0d8eb7c8105d8d6d86
# 446  4fd399eb8eb7c8105d8d68d8
# 447  59c2bfd77c459f246b62920d
# 448  4fd399ba8eb7c8105d8d60ab
# 449  59c2bfe87c459f246b62920e
# 450  4fd399a28eb7c8105d8d5d39
# 451  59c2bfe87c459f246b62920f
# 452  59c2bfe87c459f246b629210
# 453  59c2c0007c459f246b629211
# 454  4fd399f08eb7c8105d8d697b
# 455  4fd399ca8eb7c8105d8d6241
# 456  4fd39a138eb7c8105d8d6e02
# 457  59c2c0007c459f246b629212
# 458  59c2c0017c459f246b629213
# 459  4fd39a708eb7c8105d8d7ae4
#
#                                               abstract blog  \
# 0                                                  NaN   {}
# 1                                                  NaN   {}
# 2                                                  NaN   {}
# 3                                                  NaN   {}
# 4                                                  NaN   {}
# 5                                                  NaN   {}
# 6                                                  NaN   {}
# 7                                                  NaN   {}
# 8                                                  NaN   {}
# 9                                                  NaN   {}
# 10                                                 NaN   {}
# 11                                                 NaN   {}
# 12                                                 NaN   {}
# 13                                                 NaN   {}
# 14                                                 NaN   {}
# 15                                                 NaN   {}
# 16                                                 NaN   {}
# 17                                                 NaN   {}
# 18                                                 NaN   {}
# 19                                                 NaN   {}
# 20                                                 NaN   {}
# 21                                                 NaN   {}
# 22                                                 NaN   {}
# 23                                                 NaN   {}
# 24                                                 NaN   {}
# 25                                                 NaN   {}
# 26                                                 NaN   {}
# 27                                                 NaN   {}
# 28                                                 NaN   {}
# 29                                                 NaN   {}
# ..                                                 ...  ...
# 430                                                NaN   {}
# 431                                                NaN   {}
# 432  Although the festival has evolved into a showc...   {}
# 433                                                NaN   {}
# 434  6 Q&#8217;s About the News &#124; Who are play...   {}
# 435  6 Q's About the News | Who are playing at the ...   {}
# 436  The death on Wednesday of Alex Chilton, the si...   {}
# 437                                                NaN   {}
# 438  Some of the most packed shows have been by lea...   {}
# 439                                                NaN   {}
# 440  The death on Wednesday of Alex Chilton, the si...   {}
# 441  Some of the most packed shows have been by lea...   {}
# 442  Amidst all the corporate-enabled heehaws at So...   {}
# 443                                                NaN   {}
# 444  John Hiatt and the Court Yard Hounds (two of t...   {}
# 445  Amidst all the corporate-enabled heehaws at So...   {}
# 446  John Hiatt and the Court Yard Hounds (two of t...   {}
# 447  Four-word reviews of Tanlines, Best Coast, We ...   {}
# 448  Four-word reviews of Tanlines, Best Coast, We ...   {}
# 449  As visual pitches, the branding verges on pred...   {}
# 450  As visual pitches, the branding verges on pred...   {}
# 451  Austin is as serious about its cupcakes as New...   {}
# 452  Marina and the Diamonds have a Top 10 record i...   {}
# 453  Courtney Love and the new lineup of Hole playe...   {}
# 454  Austin is as serious about its cupcakes as New...   {}
# 455  Marina and the Diamonds have a Top 10 record i...   {}
# 456  Courtney Love and the new lineup of Hole playe...   {}
# 457  A slide show of photographs from South by Sout...   {}
# 458  Four-word reviews of The Coathangers, Garotas ...   {}
# 459  A slide show of photographs from South by Sout...   {}
#
#                                                 byline document_type  \
# 0    {'original': None, 'person': None, 'organizati...    multimedia
# 1    {'original': 'By MEKADO MURPHY', 'person': [{'...       article
# 2    {'original': 'By ANDREW R. CHOW', 'person': [{...       article
# 3    {'original': 'By THE ASSOCIATED PRESS', 'perso...       article
# 4    {'original': 'By MEKADO MURPHY', 'person': [{'...       article
# 5    {'original': 'By JON PARELES', 'person': [{'fi...       article
# 6    {'original': 'By THE ASSOCIATED PRESS', 'perso...       article
# 7    {'original': 'By THE ASSOCIATED PRESS', 'perso...       article
# 8    {'original': 'By MAYA SALAM', 'person': [{'fir...       article
# 9    {'original': 'By CHRIS STANFORD', 'person': [{...       article
# 10   {'original': 'By THE ASSOCIATED PRESS', 'perso...       article
# 11   {'original': None, 'person': None, 'organizati...       article
# 12   {'original': 'By GLENN KENNY', 'person': [{'fi...       article
# 13   {'original': None, 'person': None, 'organizati...      paidpost
# 14   {'original': 'By MARTIN HERBACH', 'person': [{...       article
# 15   {'original': 'By JON CARAMANICA', 'person': [{...       article
# 16   {'original': 'By KATE McLEAN and MARIO FURLONI...       article
# 17   {'original': None, 'person': None, 'organizati...    multimedia
# 18   {'original': 'By ELIZABETH BRISTOW', 'person':...       article
# 19   {'original': 'By JENNIFER SCHUESSLER', 'person...       article
# 20   {'original': 'By JORIS DEBEIJ', 'person': [{'f...       article
# 21   {'original': 'By SOPAN DEB', 'person': [{'firs...       article
# 22   {'original': 'By JON PARELES', 'person': [{'fi...       article
# 23   {'original': 'By TIM HERRERA and MICHELLE L. D...       article
# 24   {'original': 'By BRIAN X. CHEN', 'person': [{'...       article
# 25   {'original': 'By MEKADO MURPHY', 'person': [{'...       article
# 26   {'original': 'By MICHELLE HIGGINS', 'person': ...       article
# 27   {'original': 'By DEB AMLEN', 'person': [{'firs...       article
# 28   {'original': 'By MEKADO MURPHY', 'person': [{'...       article
# 29   {'original': 'By MEKADO MURPHY', 'person': [{'...       article
# ..                                                 ...           ...
# 430  {'original': 'By RANDALL STROSS', 'person': [{...       article
# 431  {'original': 'By JULIE BLOOM', 'person': [{'fi...       article
# 432  {'original': 'By DAVID MENCONI', 'person': [{'...      blogpost
# 433                                                NaN       article
# 434  {'original': 'By KATHERINE SCHULTEN', 'person'...      blogpost
# 435  {'original': 'By KATHERINE SCHULTEN', 'person'...      blogpost
# 436  {'original': 'By JON PARELES', 'person': [{'fi...      blogpost
# 437  {'original': 'David Carr', 'person': [{'firstn...    multimedia
# 438  {'original': 'By JON PARELES', 'person': [{'fi...      blogpost
# 439  {'original': None, 'person': None, 'organizati...    multimedia
# 440  {'original': 'By JON PARELES', 'person': [{'fi...      blogpost
# 441  {'original': 'By JON PARELES', 'person': [{'fi...      blogpost
# 442  {'original': 'By MELENA RYZIK', 'person': [{'f...      blogpost
# 443  {'original': 'By JON PARELES', 'person': [{'fi...       article
# 444  {'original': 'By JAN BENZEL', 'person': [{'fir...      blogpost
# 445  {'original': 'By MELENA RYZIK', 'person': [{'f...      blogpost
# 446  {'original': 'By JAN BENZEL', 'person': [{'fir...      blogpost
# 447  {'original': 'By BEN SISARIO', 'person': [{'fi...      blogpost
# 448  {'original': 'By BEN SISARIO', 'person': [{'fi...      blogpost
# 449  {'original': 'By BEN SISARIO', 'person': [{'fi...      blogpost
# 450  {'original': 'By BEN SISARIO', 'person': [{'fi...      blogpost
# 451  {'original': 'By JAN BENZEL', 'person': [{'fir...      blogpost
# 452  {'original': 'By JON PARELES', 'person': [{'fi...      blogpost
# 453  {'original': 'By JON PARELES', 'person': [{'fi...      blogpost
# 454  {'original': 'By JAN BENZEL', 'person': [{'fir...      blogpost
# 455  {'original': 'By JON PARELES', 'person': [{'fi...      blogpost
# 456  {'original': 'By JON PARELES', 'person': [{'fi...      blogpost
# 457  {'original': 'By JOSH HANER', 'person': [{'fir...      blogpost
# 458  {'original': 'By BEN SISARIO', 'person': [{'fi...      blogpost
# 459  {'original': 'By JOSH HANER', 'person': [{'fir...      blogpost
#
#                                               headline  \
# 0    {'main': 'Street Style: SXSW', 'kicker': None,...
# 1    {'main': 'SXSW Film: The Movies and Performers...
# 2    {'main': 'Roots Show at SXSW in Austin Is Canc...
# 3    {'main': 'Bill Murray Takes Catnap at SXSW Pre...
# 4    {'main': 'South by Southwest 2018: 5 Titles to...
# 5    {'main': 'South by Southwest Music Festival: 1...
# 6    {'main': 'Package Bombs in Texas Capital Likel...
# 7    {'main': 'Daly: 2022 China Games Possible for ...
# 8    {'main': '3 Austin Package Explosions, 2 of Th...
# 9    {'main': 'Facebook, Texas, China: Your Thursda...
# 10   {'main': 'The Latest: Governor Offers $15K Rew...
# 11   {'main': 'Trump Puts an End to Broadcom’s Bid ...
# 12   {'main': 'A Brief History of American Independ...
# 13   {'main': 'On the Road in 2017', 'kicker': None...
# 14   {'main': 'Head-in-the-Clouds Place', 'kicker':...
# 15   {'main': 'Northside Festival Adds Activism and...
# 16   {'main': 'Gut Hack', 'kicker': 'Op-Docs', 'con...
# 17   {'main': 'Street Style: SXSW', 'kicker': None,...
# 18   {'main': 'Street Style: SXSW', 'kicker': None,...
# 19   {'main': 'How Six Degrees Became a Forever Mem...
# 20   {'main': 'Perfectly Normal', 'kicker': 'Op-Doc...
# 21   {'main': 'After an Online Uproar, SXSW Festiva...
# 22   {'main': 'Finding the Joy at South by Southwes...
# 23   {'main': 'What to Cook, Watch, Listen To and M...
# 24   {'main': 'Riding With the Underdogs: Apps Fill...
# 25   {'main': 'South by Southwest: A Film Diary', '...
# 26   {'main': 'Where to Go for Spring Break', 'kick...
# 27   {'main': 'Queen’s Place', 'kicker': 'Wordplay'...
# 28   {'main': 'South by Southwest: 5 Titles to Watc...
# 29   {'main': 'Terrence Malick’s ‘Song to Song’ Wil...
# ..                                                 ...
# 430  {'main': 'You, Too, Can Bankroll a Rock Band',...
# 431  {'main': 'Keep It Rockin’', 'kicker': 'Music',...
# 432  {'main': 'Letter From Austin | SXSW Standouts'...
# 433  {'main': 'The Week Ahead | Mar. 28 — April 3',...
# 434  {'main': 'The 411 on SXSW', 'kicker': 'The Lea...
# 435  {'main': 'The 411 on SXSW', 'kicker': 'The Lea...
# 436  {'main': 'SXSW: A Memorial for Alex Chilton at...
# 437  {'main': 'Mashing Up Real and Digital at SXSW ...
# 438  {'main': 'SXSW: Glo-fi — Just Another Blip?', ...
# 439  {'main': 'The Menu at SXSW', 'kicker': None, '...
# 440  {'main': 'SXSW: A Memorial for Alex Chilton at...
# 441  {'main': 'SXSW: Glo-fi — Just Another Blip?', ...
# 442  {'main': 'SXSW: House Party', 'kicker': 'ArtsB...
# 443  {'main': 'Spilling Beyond a Festival’s Main Co...
# 444  {'main': 'SXSW: Outside Looking In, Inside Loo...
# 445  {'main': 'SXSW: House Party', 'kicker': 'ArtsB...
# 446  {'main': 'SXSW: Outside Looking In, Inside Loo...
# 447  {'main': 'SXSW: Four-Word Reviews From Saturda...
# 448  {'main': 'SXSW: Four-Word Reviews From Saturda...
# 449  {'main': 'SXSW: This Blog Post Was Brought to ...
# 450  {'main': 'SXSW: This Blog Post Was Brought to ...
# 451  {'main': 'SXSW: The Food Truck Diet', 'kicker'...
# 452  {'main': 'SXSW: Marina and the Diamonds', 'kic...
# 453  {'main': 'SXSW: Courtney Love, With Guitar and...
# 454  {'main': 'SXSW: The Food Truck Diet', 'kicker'...
# 455  {'main': 'SXSW: Marina and the Diamonds', 'kic...
# 456  {'main': 'SXSW: Courtney Love, With Guitar and...
# 457  {'main': 'SXSW: A Slide Show', 'kicker': 'Arts...
# 458  {'main': 'SXSW: Four-Word Reviews From Friday ...
# 459  {'main': 'SXSW: A Slide Show', 'kicker': 'Arts...
#
#                                               keywords  \
# 0    [{'name': 'subject', 'value': 'South by Southw...
# 1    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 2    [{'name': 'subject', 'value': 'South by Southw...
# 3                                                   []
# 4    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 5    [{'name': 'subject', 'value': 'South by Southw...
# 6                                                   []
# 7                                                   []
# 8    [{'name': 'glocations', 'value': 'Austin (Tex)...
# 9                                                   []
# 10                                                  []
# 11   [{'name': 'glocations', 'value': 'Saudi Arabia...
# 12   [{'name': 'subject', 'value': 'Movies', 'rank'...
# 13                                                  []
# 14   [{'name': 'subject', 'value': 'Crossword Puzzl...
# 15   [{'name': 'subject', 'value': 'Music', 'rank':...
# 16   [{'name': 'subject', 'value': 'Microbiology', ...
# 17   [{'name': 'subject', 'value': 'South by Southw...
# 18   [{'name': 'subject', 'value': 'South by Southw...
# 19   [{'name': 'subject', 'value': 'Theater', 'rank...
# 20   [{'name': 'subject', 'value': 'Autism', 'rank'...
# 21   [{'name': 'subject', 'value': 'South by Southw...
# 22   [{'name': 'subject', 'value': 'South by Southw...
# 23   [{'name': 'subject', 'value': 'Books and Liter...
# 24   [{'name': 'subject', 'value': 'Car Services an...
# 25   [{'name': 'subject', 'value': 'Movies', 'rank'...
# 26   [{'name': 'subject', 'value': 'Travel and Vaca...
# 27   [{'name': 'subject', 'value': 'Crossword Puzzl...
# 28   [{'name': 'subject', 'value': 'Movies', 'rank'...
# 29   [{'name': 'subject', 'value': 'Movies', 'rank'...
# ..                                                 ...
# 430  [{'name': 'subject', 'value': 'Music', 'rank':...
# 431                                                 []
# 432  [{'name': 'type_of_material', 'value': 'News',...
# 433                                                 []
# 434                                                 []
# 435  [{'name': 'type_of_material', 'value': 'News',...
# 436                                                 []
# 437                                                 []
# 438                                                 []
# 439  [{'name': 'subject', 'value': 'Music', 'rank':...
# 440  [{'name': 'type_of_material', 'value': 'News',...
# 441  [{'name': 'type_of_material', 'value': 'News',...
# 442                                                 []
# 443  [{'name': 'subject', 'value': 'Music', 'rank':...
# 444                                                 []
# 445  [{'name': 'type_of_material', 'value': 'News',...
# 446  [{'name': 'type_of_material', 'value': 'News',...
# 447                                                 []
# 448  [{'name': 'type_of_material', 'value': 'News',...
# 449                                                 []
# 450  [{'name': 'type_of_material', 'value': 'News',...
# 451                                                 []
# 452                                                 []
# 453                                                 []
# 454  [{'name': 'type_of_material', 'value': 'News',...
# 455  [{'name': 'type_of_material', 'value': 'News',...
# 456  [{'name': 'type_of_material', 'value': 'News',...
# 457                                                 []
# 458                                                 []
# 459  [{'name': 'type_of_material', 'value': 'News',...
#
#                                             multimedia         new_desk  \
# 0    [{'rank': 0, 'subtype': 'xlarge', 'caption': N...  Fashion & Style
# 1    [{'rank': 0, 'subtype': 'xlarge', 'caption': N...          Weekend
# 2    [{'rank': 0, 'subtype': 'xlarge', 'caption': N...          Culture
# 3                                                   []             None
# 4    [{'rank': 0, 'subtype': 'xlarge', 'caption': N...          Weekend
# 5    [{'rank': 0, 'subtype': 'xlarge', 'caption': N...          Culture
# 6                                                   []             None
# 7                                                   []             None
# 8    [{'rank': 0, 'subtype': 'xlarge', 'caption': N...          Express
# 9    [{'rank': 0, 'subtype': 'xlarge', 'caption': N...           NYTNow
# 10                                                  []             None
# 11   [{'rank': 0, 'subtype': 'xlarge', 'caption': N...         Business
# 12   [{'rank': 0, 'subtype': 'xlarge', 'caption': N...     Arts&Leisure
# 13                                                  []              NaN
# 14   [{'rank': 0, 'subtype': 'xlarge', 'caption': N...            Games
# 15   [{'rank': 0, 'subtype': 'thumbnail', 'caption'...     Arts&Leisure
# 16   [{'rank': 0, 'subtype': 'xlarge', 'caption': N...             OpEd
# 17   [{'rank': 0, 'subtype': 'xlarge', 'caption': N...  Fashion & Style
# 18                                                  []           Styles
# 19   [{'rank': 0, 'subtype': 'xlarge', 'caption': N...     Arts&Leisure
# 20   [{'rank': 0, 'subtype': 'xlarge', 'caption': N...             OpEd
# 21   [{'rank': 0, 'subtype': 'thumbnail', 'caption'...          Culture
# 22   [{'rank': 0, 'subtype': 'thumbnail', 'caption'...          Culture
# 23   [{'rank': 0, 'subtype': 'thumbnail', 'caption'...          Express
# 24   [{'rank': 0, 'subtype': 'thumbnail', 'caption'...         Business
# 25   [{'rank': 0, 'subtype': 'thumbnail', 'caption'...          Weekend
# 26   [{'rank': 0, 'subtype': 'thumbnail', 'caption'...           Travel
# 27   [{'rank': 0, 'subtype': 'xlarge', 'caption': N...            Games
# 28   [{'rank': 0, 'subtype': 'thumbnail', 'caption'...          Culture
# 29   [{'rank': 0, 'subtype': 'wide', 'caption': Non...          Weekend
# ..                                                 ...              ...
# 430  [{'rank': 0, 'subtype': 'thumbnail', 'caption'...   SundayBusiness
# 431                                                 []          Culture
# 432                                                 []              NaN
# 433  [{'rank': 0, 'subtype': 'thumbnail', 'caption'...     Arts&Leisure
# 434                                                 []              NaN
# 435                                                 []              NaN
# 436                                                 []          Culture
# 437  [{'rank': 0, 'subtype': 'wide', 'caption': Non...     Business Day
# 438                                                 []          Culture
# 439  [{'rank': 0, 'subtype': 'popup', 'caption': No...             Arts
# 440                                                 []              NaN
# 441                                                 []              NaN
# 442                                                 []          Culture
# 443  [{'rank': 0, 'subtype': 'thumbnail', 'caption'...          Culture
# 444                                                 []          Culture
# 445                                                 []              NaN
# 446                                                 []              NaN
# 447                                                 []          Culture
# 448                                                 []              NaN
# 449                                                 []          Culture
# 450                                                 []              NaN
# 451                                                 []          Culture
# 452                                                 []          Culture
# 453                                                 []          Culture
# 454                                                 []              NaN
# 455                                                 []              NaN
# 456                                                 []              NaN
# 457                                                 []          Culture
# 458                                                 []          Culture
# 459                                                 []              NaN
#
#     print_page                  pub_date         score   section_name  \
# 0          NaN  2018-03-20T14:42:40+0000  4.313703e+00            NaN
# 1          NaN  2018-03-15T18:16:41+0000  2.679814e+00            NaN
# 2          NaN  2018-03-18T16:24:38+0000  2.162063e+00          Music
# 3          NaN  2018-03-19T12:22:00+0000  2.070246e+00            NaN
# 4            9  2018-01-31T19:00:14+0000  1.643470e+00            NaN
# 5            1  2018-03-18T22:00:01+0000  5.062070e-01          Music
# 6          NaN  2018-03-12T14:31:07+0000  4.697890e-01            NaN
# 7          NaN  2018-03-10T20:03:46+0000  3.771874e-01         Hockey
# 8           11  2018-03-12T19:36:37+0000  3.571348e-01            NaN
# 9          NaN  2018-03-22T09:36:29+0000  2.706787e-01            NaN
# 10         NaN  2018-03-12T16:09:52+0000  2.683964e-01            NaN
# 11         NaN  2018-03-12T13:05:24+0000  1.677056e-01       DealBook
# 12          12  2018-01-11T20:45:24+0000  1.512996e-01            NaN
# 13         NaN  2017-12-21T17:52:25+0000  1.341083e-01            NaN
# 14         NaN  2017-09-10T22:00:01+0000  3.371099e-03            NaN
# 15           8  2017-06-01T15:34:33+0000  2.761205e-05          Music
# 16         NaN  2017-04-11T19:08:59+0000  1.508155e-06            NaN
# 17         NaN  2017-03-20T21:46:27+0000  4.514700e-07            NaN
# 18           8  2017-03-20T21:50:53+0000  3.013243e-07            NaN
# 19           1  2017-04-19T09:00:20+0000  2.829546e-07            NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# 5                                          NaN
# 6                                          NaN
# 7                                          NaN
# 8                                          NaN
# 9                                          NaN
# 10                                         NaN
# 11                                         NaN
# 12                                         NaN
# 13                                         NaN
# 14                                         NaN
# 15                                         NaN
# 16                                         NaN
# 17          Scot Redman for The New York Times
# 18                                         NaN
# 19                                         NaN
# 20                                         NaN
# 21                                         NaN
# 22                                         NaN
# 23                                         NaN
# 24                                         NaN
# 25                                         NaN
# 26                                         NaN
# 27                                         NaN
# 28                                         NaN
# 29                                         NaN
# ..                                         ...
# 430                                        NaN
# 431                                        NaN
# 432                                        NaN
# 433                                        NaN
# 434                                        NaN
# 435                                        NaN
# 436                                        NaN
# 437                                        NaN
# 438                                        NaN
# 439              Josh Haner/The New York Times
# 440                                        NaN
# 441                                        NaN
# 442                                        NaN
# 443                                        NaN
# 444                                        NaN
# 445                                        NaN
# 446                                        NaN
# 447                                        NaN
# 448                                        NaN
# 449                                        NaN
# 450                                        NaN
# 451                                        NaN
# 452                                        NaN
# 453                                        NaN
# 454                                        NaN
# 455                                        NaN
# 456                                        NaN
# 457                                        NaN
# 458                                        NaN
# 459                                        NaN
#
#                                                snippet              source  \
# 0    From street to stage, the artists who performe...  The New York Times
# 1    The South by Southwest film festival celebrate...  The New York Times
# 2    The police arrested a suspect on charges of se...  The New York Times
# 3    Bill Murray took a catnap at the premiere of t...                  AP
# 4    The South by Southwest film festival announced...  The New York Times
# 5    The lack of an arena-circuit headliner at this...  The New York Times
# 6    Two package bomb blasts a few miles apart kill...                  AP
# 7    NHL Deputy Commissioner Bill Daly says partici...                  AP
# 8    The Austin interim police chief warned residen...  The New York Times
# 9      Here’s what you need to know to start your day.  The New York Times
# 10   The Latest on deadly package bombings in Austi...                  AP
# 11   President Trump on Monday blocked Broadcom’s b...  The New York Times
# 12   Talking to John Pierson about “Split Screen,” ...  The New York Times
# 13   New data sheds light on driver behavior around...                 NaN
# 14   Erik Agard and Paolo Pasco let their minds wan...  The New York Times
# 15   As it has grown into Brooklyn’s version of SXS...  The New York Times
# 16   After a lifetime of stomach problems, Josiah Z...  The New York Times
# 17   The music-festival season begins in Austin, Te...  The New York Times
# 18   Music-festival season has begun in Austin, whi...  The New York Times
# 19   With “Six Degrees of Separation” set to return...  The New York Times
# 20   Through music and relationships, a man with As...  The New York Times
# 21   A provision that warned that musicians in the ...  The New York Times
# 22   This year’s festival featured reunions (At the...  The New York Times
# 23           Tips for making the most of your weekend.  The New York Times
# 24   The two all-but-ubiquitous ride-sharing apps n...  The New York Times
# 25   I saw some movies, chatted with some actors an...  The New York Times
# 26   From San Diego to Puerto Rico, some best bets ...  The New York Times
# 27               Finn Vigeland treats us like royalty.  The New York Times
# 28   Here are five selections — including a look at...  The New York Times
# 29   The new film, set amid the Austin music scene,...  The New York Times
# ..                                                 ...                 ...
# 430  Artists without recording contracts are turnin...  The New York Times
# 431  "Anyone who didn't make it to the musical smor...  The New York Times
# 432  Although the festival has evolved into a showc...  The New York Times
# 433                                                     The New York Times
