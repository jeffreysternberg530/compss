# %%
# Import required libraries
from __future__ import division
import requests
import json
import math
import matplotlib.pyplot as plt
import time
import pandas
import csv

# %%
key = "AIzaSyCxYOX08rJ-t2mfkAIja9H2aM0YWA2TNKQ"
base_url = "https://www.googleapis.com/blogger/v3/blogs/6505115477480098233/posts?key=AIzaSyCxYOX08rJ-t2mfkAIja9H2aM0YWA2TNKQ"
r = requests.get(base_url)

# wait 3 seconds for the GET request
time.sleep(3)

# convert to a dictionary
data = json.loads(r.text)
data
# Out:
# {'etag': '"tCegCRaUD_llG4Ci20eREslQYjU/MjAxNy0wNi0yNVQyMjoyNzowMS4zOTJa"',
#  'items': [{'author': {'displayName': 'Sophie Gong',
#     'id': 'g104753407639463684096',
#     'image': {'url': '//lh5.googleusercontent.com/-6uQacsBS9cE/AAAAAAAAAAI/AAAAAAAAA24/9OnoYYWT6Uw/s35-c/photo.jpg'},
#     'url': 'https://www.blogger.com/profile/18087548304893982878'},
#    'blog': {'id': '6505115477480098233'},
# ...

# %%
stuff = data["items"]

# %%
city = pandas.DataFrame(stuff)

# %%
city
# Out:
#                                               author  \
# 0  {'id': 'g104753407639463684096', 'displayName'...
# 1  {'id': 'g104753407639463684096', 'displayName'...
# 2  {'id': 'g104753407639463684096', 'displayName'...
# 3  {'id': 'g113991615451469722285', 'displayName'...
# 4  {'id': 'g113991615451469722285', 'displayName'...
# 5  {'id': 'g113991615451469722285', 'displayName'...
# 6  {'id': 'g103807006959602003674', 'displayName'...
# 7  {'id': '18056899800531001264', 'displayName': ...
# 8  {'id': 'g103807006959602003674', 'displayName'...
# 9  {'id': 'g103807006959602003674', 'displayName'...
#
#                             blog  \
# 0  {'id': '6505115477480098233'}
# 1  {'id': '6505115477480098233'}
# 2  {'id': '6505115477480098233'}
# 3  {'id': '6505115477480098233'}
# 4  {'id': '6505115477480098233'}
# 5  {'id': '6505115477480098233'}
# 6  {'id': '6505115477480098233'}
# 7  {'id': '6505115477480098233'}
# 8  {'id': '6505115477480098233'}
# 9  {'id': '6505115477480098233'}
#
# ...
